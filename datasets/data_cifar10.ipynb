# %% [markdown]
# ### CIFAR-10 dataset
#
# reference: https://www.cs.toronto.edu/~kriz/cifar.html

# %%
import torch
import torchvision
from torchvision.transforms import v2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Load the data

# %%
transform = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 4

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

# %% [markdown]
# ### Examine the dataset

# %%
# labels
print ("\nLabels:", train_dataset.classes)

# classes of the images
print ("\nClasses of first 100 images:", train_dataset.targets[:100])

X = train_dataset.data

print (X.shape)

X_mean = X.mean()
X_std = X.std()

print ("\nMean and std:", X_mean, X_std)

print (X.shape, X.min(), X.max())

# %% [markdown]
# ### display some pictures from the dataset

# %%
num_examples = 10
plt.figure(figsize=(8, 4))
# visualize the images .data
for i in range(num_examples):
    plt.subplot(1, num_examples, i + 1)
    plt.imshow(X[i], cmap='gray')
    plt.axis('off')

# %% [markdown]
# ### show pictures according to labels

# %%
# number of images to show 
num_examples = 5

print ('labels=', train_dataset.classes)

# loop over labels
for label in range(10):
    
    # select indices with the matching label
    indices = torch.where(torch.tensor(train_dataset.targets) == label)[0]
    plt.figure(figsize=(4, 2))
    for i in range(num_examples):
        plt.subplot(1, num_examples, i + 1)
        plt.imshow(X[indices[i]], cmap='gray')
        plt.axis('off')

# %% [markdown]
# ### If necessary, normalize the data

# %%
# normalize the image data

X_mean = X.mean()
X_std = X.std()
X = (X-X_mean) / X_std

print ("\nMean and std:", X_mean, X_std)

print (X.shape, X.min(), X.max())
